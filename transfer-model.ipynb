# %%
import os
import sys
import numpy as np 
sys.path.append('./')

from encoder import ConformerEncoder, ConformerBlock

import librosa
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# %%
# Dataset setup
class TimbreDataset(Dataset):
    def __init__(self, root_dir, instrument_to_label, extension, sample_rate=44100, duration_ms=500, n_mels=128):
        self.samples = []
        self.labels = []
        self.sr = sample_rate
        self.clip_len = int(sample_rate * duration_ms / 1000)
        self.n_mels = n_mels
        self.instrument_to_label = instrument_to_label
         
        # preprocess
        for instrument, label in instrument_to_label.items():
            print(f"Preprocessing {instrument} data with label {label}:")
            inst_dir = os.path.join(root_dir, instrument)

            count_1 = 0 # counter for visualization purposes
            count_2 = 0
            count_3 = 0

            if not os.path.isdir(inst_dir):
                continue  # Skip if not a valid directory
            for file in os.listdir(inst_dir):
            # for file in sorted(os.listdir(inst_dir)):
                # print(file)
                if file.endswith(extension):
                    file_path = os.path.join(inst_dir, file)

                    try:
                        # Attempt to load the file
                        y, _ = librosa.load(file_path, sr=self.sr)

                        y_trim, _ = librosa.effects.trim(y, top_db=30) # removing anything below 30 dB

                        # plot full waveforms
                        if count_2 < 1:
                            duration = len(y_trim) / self.sr
                            time = np.linspace(0, duration, len(y_trim))

                            plt.figure(figsize=(14, 5))
                            plt.plot(time, y_trim)
                            plt.title(f"Full Waveform of {file}")
                            plt.xlabel("Time (seconds)")
                            plt.ylabel("Amplitude")
                            plt.show()

                            count_2 += 1

                        clip = y_trim[:self.clip_len]
                        if len(clip) < self.clip_len:
                            clip = np.pad(clip, (0, self.clip_len - len(clip)))
                        mel = librosa.feature.melspectrogram(y=clip, sr=self.sr, n_mels=self.n_mels)
                        log_mel = librosa.power_to_db(mel, ref=np.max)

                        # plot full mel spectrograms
                        if count_3 < 1:
                            full_mel = librosa.feature.melspectrogram(y=y, sr=self.sr, n_mels=self.n_mels)
                            full_log_mel = librosa.power_to_db(full_mel, ref=np.max)
                            duration = len(y) / self.sr
                            time = np.linspace(0, duration, full_mel.shape[-1])

                            plt.figure(figsize=(8, 5))
                            librosa.display.specshow(full_log_mel, y_axis='mel', x_axis='time', sr=self.sr)
                            plt.title(f"Full Log Mel Spectrogram of {file}")
                            plt.xlabel("Time (seconds)")
                            plt.ylabel("Frequency (Mel)")
                            plt.colorbar(format='%+2.0f dB')
                            plt.show()

                            count_3 += 1
                
                        # Ensure the time axis is fixed length
                        target_frames = 50
                        if log_mel.shape[1] < target_frames:
                            pad_width = target_frames - log_mel.shape[1]
                            log_mel = np.pad(log_mel, ((0, 0), (0, pad_width)), mode='constant')
                        else:
                            log_mel = log_mel[:, :target_frames]

                        # self.samples.append(file_path)
                        self.samples.append(log_mel)
                        self.labels.append(label)
                    except Exception as e:
                        # Log the issue and skip the corrupted file
                        print(f"[Error] Skipping {file_path}: {e}")
                        continue  # Skip this file and continue with the rest

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        # Fetch preprocessed mel spectrogram and corresponding label
        log_mel = self.samples[idx]
        label = self.labels[idx]

        # Return the preprocessed data and label
        return torch.tensor(log_mel, dtype=torch.float32).unsqueeze(0), torch.tensor(label, dtype=torch.long)

        # file_path = self.samples[idx]
        # label = self.labels[idx]
        # try:
        #     y, _ = librosa.load(file_path, sr=self.sr)
        #     y_trim, _ = librosa.effects.trim(y, top_db=30)
        #     clip = y_trim[:self.clip_len]
        #     if len(clip) < self.clip_len:
        #         clip = np.pad(clip, (0, self.clip_len - len(clip)))
        #     mel = librosa.feature.melspectrogram(y=clip, sr=self.sr, n_mels=self.n_mels)
        #     log_mel = librosa.power_to_db(mel, ref=np.max)
            
        #     # Ensure the time axis is fixed length
        #     target_frames = 22  # whatever size you want
        #     if log_mel.shape[1] < target_frames:
        #         pad_width = target_frames - log_mel.shape[1]
        #         log_mel = np.pad(log_mel, ((0, 0), (0, pad_width)), mode='constant')
        #     else:
        #         log_mel = log_mel[:, :target_frames]

        #     return torch.tensor(log_mel, dtype=torch.float32).unsqueeze(0), torch.tensor(label, dtype=torch.long)
        # except Exception as e:
        #     print(f"[Error] Skipping {file_path}: {e}")
        #     raise e

# %%
# Model definition
class ConformerClassifier(nn.Module):
    def __init__(self, input_dim=128, num_classes=6, num_blocks=4, hidden_dim=144, num_heads=4, dropout=0.1):
        super(ConformerClassifier, self).__init__()
        self.input_proj = nn.Conv1d(input_dim, hidden_dim, kernel_size=1)
        self.conformer_blocks = nn.Sequential(*[
            ConformerBlock(
                encoder_dim=hidden_dim,
                num_attention_heads=num_heads,
                feed_forward_expansion_factor=4,
                conv_expansion_factor=2,
                feed_forward_dropout_p=dropout,
                attention_dropout_p=dropout,
                conv_dropout_p=dropout,
                conv_kernel_size=31,
                half_step_residual=True
            ) for _ in range(num_blocks)
        ])
        self.pooling = nn.AdaptiveAvgPool1d(1)
        self.classifier = nn.Linear(hidden_dim, num_classes)

    def forward(self, x):
        x = x.squeeze(1)  # From (B, 1, F, T) to (B, F, T)
        x = self.input_proj(x)  # (B, hidden_dim, T)
        x = x.transpose(1, 2)   # (B, T, hidden_dim) for conformer
        x = self.conformer_blocks(x)
        x = x.transpose(1, 2)   # Back to (B, hidden_dim, T)
        x = self.pooling(x).squeeze(-1)  # (B, hidden_dim)
        return self.classifier(x)

def spec_augment(mel_spec, time_mask_param=20, freq_mask_param=10):
    # mel_spec: Tensor of shape (F, T)
    augmented = mel_spec.clone()

    # Time masking
    T = augmented.shape[1]
    t = torch.randint(0, time_mask_param + 1, (1,)).item()
    if T - t > 0:
        t0 = torch.randint(0, T - t, (1,)).item()
        augmented[:, t0:t0 + t] = 0

    # Frequency masking
    F = augmented.shape[0]
    f = torch.randint(0, freq_mask_param + 1, (1,)).item()
    if F - f > 0:
        f0 = torch.randint(0, F - f, (1,)).item()
        augmented[f0:f0 + f, :] = 0

    return augmented

# %% [markdown]
# ## Phase 1: Training on LPO Dataset

# %%
# class mapping
lpo_classes = ["cello", "clarinet", "flute", "saxophone", "trumpet", "violin"] 

# classes = ['violin', 'viola', 'cello', 'double bass', 'clarinet', 'bass clarinet', 'saxophone', 'flute',
#            'oboe', 'bassoon', 'contrabassoon', 'cor anglais', 'french horn', 'trombone', 'trumpet', 'tuba',
#             'guitar', 'mandolin', 'banjo', 'percussion']

instrument_to_label = {name: idx for idx, name in enumerate(lpo_classes)}
print(instrument_to_label)

# load lpo data (all of it will be used to train)
lpo_ds = TimbreDataset("data/all-samples", instrument_to_label, ".mp3")
lpo_loader = DataLoader(lpo_ds, batch_size=16, shuffle=True, num_workers=0)
lpo_labels = [int(label) for _, label in lpo_ds]

# count
lpo_counts = Counter(lpo_labels)

print("LPO Training Set Counts:", lpo_counts)
# Out:
# {'cello': 0, 'clarinet': 1, 'flute': 2, 'saxophone': 3, 'trumpet': 4, 'violin': 5}
# Preprocessing cello data with label 0:
# Preprocessing clarinet data with label 1:
# Preprocessing flute data with label 2:
# Preprocessing saxophone data with label 3:
# Preprocessing trumpet data with label 4:
# Preprocessing violin data with label 5:
# LPO Training Set Counts: Counter({5: 1502, 0: 889, 2: 878, 1: 846, 3: 732, 4: 485})

# %%
# Device + model
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ConformerClassifier(input_dim=128, num_classes=len(lpo_classes)).to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
criterion_ce = nn.CrossEntropyLoss()

# Phase 1: Pretraining on monophonic (LPO) data
for epoch in range(1):
    model.train()
    running_loss = 0.0
    for x_batch, y_batch in lpo_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        optimizer.zero_grad()
        preds = model(x_batch)
        loss = criterion_ce(preds, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    print(f"Phase 1 - Epoch {epoch+1}, Loss: {running_loss/len(lpo_loader):.4f}")
# Out:
# Phase 1 - Epoch 1, Loss: 0.7460

# %% [markdown]
# ## Phase 2: Training on IRMAS Dataset

# %%
# class mapping
irmas_classes = ["cello", "clarinet", "flute", "saxophone", "trumpet", "violin"] 

# classes = ['violin', 'viola', 'cello', 'double bass', 'clarinet', 'bass clarinet', 'saxophone', 'flute',
#            'oboe', 'bassoon', 'contrabassoon', 'cor anglais', 'french horn', 'trombone', 'trumpet', 'tuba',
#             'guitar', 'mandolin', 'banjo', 'percussion']

# Splitting
dataset = TimbreDataset("data/irmas", instrument_to_label, ".wav")
train_size = int(0.7 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_ds, val_ds, test_ds = random_split(dataset, [train_size, val_size, test_size])

train_loader = DataLoader(train_ds, batch_size=16, shuffle=True, num_workers=0)
val_loader = DataLoader(val_ds, batch_size=16, shuffle=False, num_workers=0)

# Visualize split to make sure it's as expected
train_labels = [int(label) for _, label in train_ds]
val_labels = [int(label) for _, label in val_ds]
test_labels = [int(label) for _, label in test_ds]

# Count them
train_counts = Counter(train_labels)
val_counts = Counter(val_labels)
test_counts = Counter(test_labels)

print("Training Set Counts:", train_counts)
print("Validation Set Counts:", val_counts)
print("Test Set Counts:", test_counts)
# Out:
# Preprocessing cello data with label 0:
# Preprocessing clarinet data with label 1:
# Preprocessing flute data with label 2:
# Preprocessing saxophone data with label 3:
# Preprocessing trumpet data with label 4:
# Preprocessing violin data with label 5:
# Training Set Counts: Counter({3: 446, 5: 405, 4: 390, 1: 370, 2: 305, 0: 272})
# Validation Set Counts: Counter({3: 68, 5: 58, 4: 58, 2: 48, 1: 43, 0: 37})
# Test Set Counts: Counter({4: 129, 5: 117, 3: 112, 2: 98, 1: 92, 0: 79})

# %%
# # Device + model
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model = ConformerClassifier(input_dim=128, num_classes=len(irmas_classes)).to(device)
# optimizer = torch.optim.Adam(model.parameters(), lr=1e-4)
# criterion_ce = nn.CrossEntropyLoss()

# Reset classifier head if needed for IRMAS (polyphonic)
if model.classifier.out_features != len(irmas_classes):
    model.classifier = nn.Linear(model.classifier.in_features, len(irmas_classes)).to(device)

# Phase 2: Finetuning on polyphonic (IRMAS) data
for epoch in range(20):
    model.train()
    running_loss = 0.0
    for x_batch, y_batch in train_loader:
        x_batch = x_batch.to(device)
        y_batch = y_batch.to(device)

        # Apply SpecAugment during training
        for i in range(x_batch.size(0)):
            x_batch[i, 0] = spec_augment(x_batch[i, 0])

        optimizer.zero_grad()
        preds = model(x_batch)
        loss = criterion_ce(preds, y_batch)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
    print(f"Phase 2 - Epoch {epoch+1}, Loss: {running_loss/len(train_loader):.4f}")
# Out:
# Phase 2 - Epoch 1, Loss: 1.7724
# Phase 2 - Epoch 2, Loss: 1.5441
# Phase 2 - Epoch 3, Loss: 1.4576
# Phase 2 - Epoch 4, Loss: 1.3943
# Phase 2 - Epoch 5, Loss: 1.3529
# Phase 2 - Epoch 6, Loss: 1.2890
# Phase 2 - Epoch 7, Loss: 1.2589
# Phase 2 - Epoch 8, Loss: 1.2288
# Phase 2 - Epoch 9, Loss: 1.1541
# Phase 2 - Epoch 10, Loss: 1.1255
# Phase 2 - Epoch 11, Loss: 1.0604
# Phase 2 - Epoch 12, Loss: 1.0161
# Phase 2 - Epoch 13, Loss: 0.9536
# Phase 2 - Epoch 14, Loss: 0.9220
# Phase 2 - Epoch 15, Loss: 0.8531
# Phase 2 - Epoch 16, Loss: 0.7994
# Phase 2 - Epoch 17, Loss: 0.7579
# Phase 2 - Epoch 18, Loss: 0.6708
# Phase 2 - Epoch 19, Loss: 0.6294
# Phase 2 - Epoch 20, Loss: 0.5618

# %% [markdown]
# ## Validating

# %%
# Evaluation on validation set
model.eval()
all_preds = []
all_targets = []
correct_predictions = 0
total_predictions = 0

with torch.no_grad():
    for x_batch, y_batch in val_loader:
        try:
            x_batch = x_batch.to(device)
            y_batch = y_batch.to(device)
            preds = model(x_batch)
            pred_labels = torch.argmax(preds, dim=1)
            all_preds.extend(pred_labels.cpu().numpy())
            all_targets.extend(y_batch.cpu().numpy())

            # Calculate correct predictions and total predictions for accuracy
            correct_predictions += (pred_labels == y_batch).sum().item()
            total_predictions += y_batch.size(0)

        except Exception as e:
            print(f"[Skipping batch due to error]: {e}")
            continue

# Save model for interpretability analysis
model_path = "models/transfer_model.pth"
torch.save(model.state_dict(), model_path)

if len(all_targets) > 0 and len(all_preds) > 0:
    # evaluation metrics
    precision = precision_score(all_targets, all_preds, average='macro', zero_division=0)
    recall = recall_score(all_targets, all_preds, average='macro', zero_division=0)
    f1 = f1_score(all_targets, all_preds, average='macro', zero_division=0)
    accuracy = correct_predictions / total_predictions
    print(f"\nPrecision: {precision:.3f}, Recall: {recall:.3f}, F1 Score: {f1:.3f}, Accuracy: {accuracy:.3f}")

    # Confusion Matrix Plot
    cm = confusion_matrix(all_targets, all_preds)
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=False, fmt="d", cmap="YlGnBu", xticklabels=irmas_classes, yticklabels=irmas_classes, cbar_kws={'label': 'Intensity'}, square=True)
    plt.xlabel("Predicted")
    plt.ylabel("True")
    plt.title("Confusion Matrix")
    plt.tight_layout()
    plt.show()
else:
    print("[Warning] No predictions made — confusion matrix cannot be computed.")
# Out:
# Precision: 0.493, Recall: 0.475, F1 Score: 0.440, Accuracy: 0.452

# %% [markdown]
# ## Interpretability Analysis

# %%
# load in model
model_path = "models/conformer_classifier.pth"
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = ConformerClassifier(input_dim=128, num_classes=len(classes)).to(device)

model.load_state_dict(torch.load(model_path, map_location=device))
model.eval()

for name, module in model.named_modules():
    print(name)

attention_layer = model.conformer_blocks[0].sequential[1].module.attention
print(vars(attention_layer))
# Out:
# input_proj
# conformer_blocks
# conformer_blocks.0
# conformer_blocks.0.sequential
# conformer_blocks.0.sequential.0
# conformer_blocks.0.sequential.0.module
# conformer_blocks.0.sequential.0.module.sequential
# conformer_blocks.0.sequential.0.module.sequential.0
# conformer_blocks.0.sequential.0.module.sequential.1
# conformer_blocks.0.sequential.0.module.sequential.1.linear
# conformer_blocks.0.sequential.0.module.sequential.2
# conformer_blocks.0.sequential.0.module.sequential.3
# conformer_blocks.0.sequential.0.module.sequential.4
# conformer_blocks.0.sequential.0.module.sequential.4.linear
# conformer_blocks.0.sequential.0.module.sequential.5
# conformer_blocks.0.sequential.1
# conformer_blocks.0.sequential.1.module
# conformer_blocks.0.sequential.1.module.positional_encoding
# conformer_blocks.0.sequential.1.module.layer_norm
# conformer_blocks.0.sequential.1.module.attention
# conformer_blocks.0.sequential.1.module.attention.query_proj
# conformer_blocks.0.sequential.1.module.attention.query_proj.linear
# conformer_blocks.0.sequential.1.module.attention.key_proj
# conformer_blocks.0.sequential.1.module.attention.key_proj.linear
# conformer_blocks.0.sequential.1.module.attention.value_proj
# conformer_blocks.0.sequential.1.module.attention.value_proj.linear
# conformer_blocks.0.sequential.1.module.attention.pos_proj
# conformer_blocks.0.sequential.1.module.attention.pos_proj.linear
# conformer_blocks.0.sequential.1.module.attention.dropout
# conformer_blocks.0.sequential.1.module.attention.out_proj
# conformer_blocks.0.sequential.1.module.attention.out_proj.linear
# conformer_blocks.0.sequential.1.module.dropout
# conformer_blocks.0.sequential.2
# conformer_blocks.0.sequential.2.module
# conformer_blocks.0.sequential.2.module.sequential
# conformer_blocks.0.sequential.2.module.sequential.0
# conformer_blocks.0.sequential.2.module.sequential.1
# conformer_blocks.0.sequential.2.module.sequential.2
# conformer_blocks.0.sequential.2.module.sequential.2.conv
# conformer_blocks.0.sequential.2.module.sequential.3
# conformer_blocks.0.sequential.2.module.sequential.4
# conformer_blocks.0.sequential.2.module.sequential.4.conv
# conformer_blocks.0.sequential.2.module.sequential.5
# conformer_blocks.0.sequential.2.module.sequential.6
# conformer_blocks.0.sequential.2.module.sequential.7
# conformer_blocks.0.sequential.2.module.sequential.7.conv
# conformer_blocks.0.sequential.2.module.sequential.8
# conformer_blocks.0.sequential.3
# conformer_blocks.0.sequential.3.module
# conformer_blocks.0.sequential.3.module.sequential
# conformer_blocks.0.sequential.3.module.sequential.0
# conformer_blocks.0.sequential.3.module.sequential.1
# conformer_blocks.0.sequential.3.module.sequential.1.linear
# conformer_blocks.0.sequential.3.module.sequential.2
# conformer_blocks.0.sequential.3.module.sequential.3
# conformer_blocks.0.sequential.3.module.sequential.4
# conformer_blocks.0.sequential.3.module.sequential.4.linear
# conformer_blocks.0.sequential.3.module.sequential.5
# conformer_blocks.0.sequential.4
# conformer_blocks.1
# conformer_blocks.1.sequential
# conformer_blocks.1.sequential.0
# conformer_blocks.1.sequential.0.module
# conformer_blocks.1.sequential.0.module.sequential
# conformer_blocks.1.sequential.0.module.sequential.0
# conformer_blocks.1.sequential.0.module.sequential.1
# conformer_blocks.1.sequential.0.module.sequential.1.linear
# conformer_blocks.1.sequential.0.module.sequential.2
# conformer_blocks.1.sequential.0.module.sequential.3
# conformer_blocks.1.sequential.0.module.sequential.4
# conformer_blocks.1.sequential.0.module.sequential.4.linear
# conformer_blocks.1.sequential.0.module.sequential.5
# conformer_blocks.1.sequential.1
# conformer_blocks.1.sequential.1.module
# conformer_blocks.1.sequential.1.module.positional_encoding
# conformer_blocks.1.sequential.1.module.layer_norm
# conformer_blocks.1.sequential.1.module.attention
# conformer_blocks.1.sequential.1.module.attention.query_proj
# conformer_blocks.1.sequential.1.module.attention.query_proj.linear
# conformer_blocks.1.sequential.1.module.attention.key_proj
# conformer_blocks.1.sequential.1.module.attention.key_proj.linear
# conformer_blocks.1.sequential.1.module.attention.value_proj
# conformer_blocks.1.sequential.1.module.attention.value_proj.linear
# conformer_blocks.1.sequential.1.module.attention.pos_proj
# conformer_blocks.1.sequential.1.module.attention.pos_proj.linear
# conformer_blocks.1.sequential.1.module.attention.dropout
# conformer_blocks.1.sequential.1.module.attention.out_proj
# conformer_blocks.1.sequential.1.module.attention.out_proj.linear
# conformer_blocks.1.sequential.1.module.dropout
# conformer_blocks.1.sequential.2
# conformer_blocks.1.sequential.2.module
# conformer_blocks.1.sequential.2.module.sequential
# conformer_blocks.1.sequential.2.module.sequential.0
# conformer_blocks.1.sequential.2.module.sequential.1
# conformer_blocks.1.sequential.2.module.sequential.2
# conformer_blocks.1.sequential.2.module.sequential.2.conv
# conformer_blocks.1.sequential.2.module.sequential.3
# conformer_blocks.1.sequential.2.module.sequential.4
# conformer_blocks.1.sequential.2.module.sequential.4.conv
# conformer_blocks.1.sequential.2.module.sequential.5
# conformer_blocks.1.sequential.2.module.sequential.6
# conformer_blocks.1.sequential.2.module.sequential.7
# conformer_blocks.1.sequential.2.module.sequential.7.conv
# conformer_blocks.1.sequential.2.module.sequential.8
# conformer_blocks.1.sequential.3
# conformer_blocks.1.sequential.3.module
# conformer_blocks.1.sequential.3.module.sequential
# conformer_blocks.1.sequential.3.module.sequential.0
# conformer_blocks.1.sequential.3.module.sequential.1
# conformer_blocks.1.sequential.3.module.sequential.1.linear
# conformer_blocks.1.sequential.3.module.sequential.2
# conformer_blocks.1.sequential.3.module.sequential.3
# conformer_blocks.1.sequential.3.module.sequential.4
# conformer_blocks.1.sequential.3.module.sequential.4.linear
# conformer_blocks.1.sequential.3.module.sequential.5
# conformer_blocks.1.sequential.4
# conformer_blocks.2
# conformer_blocks.2.sequential
# conformer_blocks.2.sequential.0
# conformer_blocks.2.sequential.0.module
# conformer_blocks.2.sequential.0.module.sequential
# conformer_blocks.2.sequential.0.module.sequential.0
# conformer_blocks.2.sequential.0.module.sequential.1
# conformer_blocks.2.sequential.0.module.sequential.1.linear
# conformer_blocks.2.sequential.0.module.sequential.2
# conformer_blocks.2.sequential.0.module.sequential.3
# conformer_blocks.2.sequential.0.module.sequential.4
# conformer_blocks.2.sequential.0.module.sequential.4.linear
# conformer_blocks.2.sequential.0.module.sequential.5
# conformer_blocks.2.sequential.1
# conformer_blocks.2.sequential.1.module
# conformer_blocks.2.sequential.1.module.positional_encoding
# conformer_blocks.2.sequential.1.module.layer_norm
# conformer_blocks.2.sequential.1.module.attention
# conformer_blocks.2.sequential.1.module.attention.query_proj
# conformer_blocks.2.sequential.1.module.attention.query_proj.linear
# conformer_blocks.2.sequential.1.module.attention.key_proj
# conformer_blocks.2.sequential.1.module.attention.key_proj.linear
# conformer_blocks.2.sequential.1.module.attention.value_proj
# conformer_blocks.2.sequential.1.module.attention.value_proj.linear
# conformer_blocks.2.sequential.1.module.attention.pos_proj
# conformer_blocks.2.sequential.1.module.attention.pos_proj.linear
# conformer_blocks.2.sequential.1.module.attention.dropout
# conformer_blocks.2.sequential.1.module.attention.out_proj
# conformer_blocks.2.sequential.1.module.attention.out_proj.linear
# conformer_blocks.2.sequential.1.module.dropout
# conformer_blocks.2.sequential.2
# conformer_blocks.2.sequential.2.module
# conformer_blocks.2.sequential.2.module.sequential
# conformer_blocks.2.sequential.2.module.sequential.0
# conformer_blocks.2.sequential.2.module.sequential.1
# conformer_blocks.2.sequential.2.module.sequential.2
# conformer_blocks.2.sequential.2.module.sequential.2.conv
# conformer_blocks.2.sequential.2.module.sequential.3
# conformer_blocks.2.sequential.2.module.sequential.4
# conformer_blocks.2.sequential.2.module.sequential.4.conv
# conformer_blocks.2.sequential.2.module.sequential.5
# conformer_blocks.2.sequential.2.module.sequential.6
# conformer_blocks.2.sequential.2.module.sequential.7
# conformer_blocks.2.sequential.2.module.sequential.7.conv
# conformer_blocks.2.sequential.2.module.sequential.8
# conformer_blocks.2.sequential.3
# conformer_blocks.2.sequential.3.module
# conformer_blocks.2.sequential.3.module.sequential
# conformer_blocks.2.sequential.3.module.sequential.0
# conformer_blocks.2.sequential.3.module.sequential.1
# conformer_blocks.2.sequential.3.module.sequential.1.linear
# conformer_blocks.2.sequential.3.module.sequential.2
# conformer_blocks.2.sequential.3.module.sequential.3
# conformer_blocks.2.sequential.3.module.sequential.4
# conformer_blocks.2.sequential.3.module.sequential.4.linear
# conformer_blocks.2.sequential.3.module.sequential.5
# conformer_blocks.2.sequential.4
# conformer_blocks.3
# conformer_blocks.3.sequential
# conformer_blocks.3.sequential.0
# conformer_blocks.3.sequential.0.module
# conformer_blocks.3.sequential.0.module.sequential
# conformer_blocks.3.sequential.0.module.sequential.0
# conformer_blocks.3.sequential.0.module.sequential.1
# conformer_blocks.3.sequential.0.module.sequential.1.linear
# conformer_blocks.3.sequential.0.module.sequential.2
# conformer_blocks.3.sequential.0.module.sequential.3
# conformer_blocks.3.sequential.0.module.sequential.4
# conformer_blocks.3.sequential.0.module.sequential.4.linear
# conformer_blocks.3.sequential.0.module.sequential.5
# conformer_blocks.3.sequential.1
# conformer_blocks.3.sequential.1.module
# conformer_blocks.3.sequential.1.module.positional_encoding
# conformer_blocks.3.sequential.1.module.layer_norm
# conformer_blocks.3.sequential.1.module.attention
# conformer_blocks.3.sequential.1.module.attention.query_proj
# conformer_blocks.3.sequential.1.module.attention.query_proj.linear
# conformer_blocks.3.sequential.1.module.attention.key_proj
# conformer_blocks.3.sequential.1.module.attention.key_proj.linear
# conformer_blocks.3.sequential.1.module.attention.value_proj
# conformer_blocks.3.sequential.1.module.attention.value_proj.linear
# conformer_blocks.3.sequential.1.module.attention.pos_proj
# conformer_blocks.3.sequential.1.module.attention.pos_proj.linear
# conformer_blocks.3.sequential.1.module.attention.dropout
# conformer_blocks.3.sequential.1.module.attention.out_proj
# conformer_blocks.3.sequential.1.module.attention.out_proj.linear
# conformer_blocks.3.sequential.1.module.dropout
# conformer_blocks.3.sequential.2
# conformer_blocks.3.sequential.2.module
# conformer_blocks.3.sequential.2.module.sequential
# conformer_blocks.3.sequential.2.module.sequential.0
# conformer_blocks.3.sequential.2.module.sequential.1
# conformer_blocks.3.sequential.2.module.sequential.2
# conformer_blocks.3.sequential.2.module.sequential.2.conv
# conformer_blocks.3.sequential.2.module.sequential.3
# conformer_blocks.3.sequential.2.module.sequential.4
# conformer_blocks.3.sequential.2.module.sequential.4.conv
# conformer_blocks.3.sequential.2.module.sequential.5
# conformer_blocks.3.sequential.2.module.sequential.6
# conformer_blocks.3.sequential.2.module.sequential.7
# conformer_blocks.3.sequential.2.module.sequential.7.conv
# conformer_blocks.3.sequential.2.module.sequential.8
# conformer_blocks.3.sequential.3
# conformer_blocks.3.sequential.3.module
# conformer_blocks.3.sequential.3.module.sequential
# conformer_blocks.3.sequential.3.module.sequential.0
# conformer_blocks.3.sequential.3.module.sequential.1
# conformer_blocks.3.sequential.3.module.sequential.1.linear
# conformer_blocks.3.sequential.3.module.sequential.2
# conformer_blocks.3.sequential.3.module.sequential.3
# conformer_blocks.3.sequential.3.module.sequential.4
# conformer_blocks.3.sequential.3.module.sequential.4.linear
# conformer_blocks.3.sequential.3.module.sequential.5
# conformer_blocks.3.sequential.4
# pooling
# classifier
# {'training': False, '_parameters': {'u_bias': Parameter containing:
# tensor([[-3.0349e-01, -2.9298e-02, -2.9394e-01,  2.0374e-01,  3.6188e-01,
#          -3.7276e-01, -3.3380e-01,  3.2409e-01, -3.7187e-01,  2.2454e-01,
#           1.2529e-01, -1.2656e-01, -3.6132e-01, -8.4757e-02, -2.7626e-02,
#          -1.0876e-01,  1.1060e-01,  9.6523e-02,  2.7166e-01, -2.4606e-01,
#           2.3474e-01, -3.1294e-01,  2.4537e-04, -3.0176e-02, -2.0244e-01,
#           8.5395e-02,  3.4067e-01,  3.1956e-01, -2.9123e-01, -3.1825e-01,
#           1.9898e-01,  2.8177e-01,  3.5069e-01,  3.6472e-02, -3.0027e-02,
#          -1.1989e-01],
#         [ 8.1837e-02, -3.8358e-02,  4.2463e-02,  3.5824e-02,  1.7486e-01,
#           3.5263e-02, -1.3371e-01,  1.6838e-01, -3.8375e-01,  2.3539e-01,
#           3.0952e-01,  2.2408e-01, -1.5929e-01, -1.0243e-01, -2.8399e-01,
#          -1.3446e-02,  5.8654e-02, -3.7403e-01, -3.9633e-01, -2.5650e-01,
#           1.5787e-01,  8.1966e-02, -1.7680e-01, -2.8219e-01, -3.5552e-01,
#           1.4839e-01,  2.7195e-01,  2.9696e-01,  1.2077e-01, -3.8244e-01,
#           2.3661e-02,  8.2468e-02,  1.0222e-01, -2.5856e-01,  5.8251e-02,
#           5.6744e-02],
#         [ 5.6976e-02,  3.2844e-01, -3.4628e-01, -1.5445e-02, -1.8026e-01,
#           3.3299e-01,  9.8676e-02, -1.0329e-01, -2.5311e-01, -2.1040e-01,
#           1.8068e-01,  1.7861e-01, -5.1739e-02,  2.1097e-01, -2.8567e-01,
#           3.5305e-01,  2.3324e-01, -7.6298e-02, -6.3620e-02, -9.1403e-02,
#          -3.1333e-01, -2.5685e-01,  2.9260e-01, -1.4716e-01,  2.9766e-01,
#          -2.7937e-01,  1.8013e-01, -1.2365e-02,  9.4246e-02, -7.0216e-02,
#          -2.7228e-01, -7.2450e-03,  2.3643e-01,  3.2321e-01,  1.9030e-01,
#          -8.7629e-02],
#         [ 3.1016e-01,  2.6968e-01, -3.1661e-01,  7.4327e-02, -9.1563e-02,
#          -4.9676e-02, -1.9010e-01,  3.4766e-01,  4.5919e-02, -2.9833e-01,
#          -3.4741e-01,  1.4260e-01,  2.6109e-01, -1.6976e-01, -6.3336e-02,
#          -2.1374e-01,  3.5558e-01, -3.0931e-01, -3.2916e-01, -1.9019e-02,
#           7.8084e-02, -3.7737e-01, -3.5218e-01,  1.9952e-01,  1.0247e-01,
#          -3.4408e-01, -7.0283e-02,  2.8696e-01, -3.0597e-01, -9.3718e-02,
#           3.4636e-01, -3.4524e-01, -2.6760e-01, -3.6909e-01,  1.9737e-01,
#           3.5352e-01]], requires_grad=True), 'v_bias': Parameter containing:
# tensor([[-0.3461, -0.2773,  0.0058, -0.3699,  0.2830, -0.2581, -0.1793, -0.2888,
#           0.0907, -0.2549,  0.2056,  0.2456,  0.0974, -0.1500,  0.3721, -0.0730,
#          -0.0504,  0.0313, -0.3097, -0.0693,  0.2298,  0.0907, -0.3756, -0.2655,
#           0.0700, -0.2577, -0.3002, -0.2709,  0.0613,  0.3614,  0.2928,  0.1742,
#          -0.3162, -0.2010,  0.0166,  0.1427],
#         [-0.3445, -0.0853,  0.1401, -0.2388, -0.3186, -0.3440, -0.1189, -0.3689,
#          -0.2159,  0.0229,  0.2644, -0.3780,  0.2760,  0.1347,  0.2763,  0.0849,
#          -0.0961, -0.2127,  0.2330, -0.3822,  0.1795,  0.3655, -0.1972,  0.2164,
#           0.2845,  0.3789, -0.1496,  0.0817, -0.3575, -0.1656, -0.0387, -0.3247,
#           0.1272,  0.3635,  0.3437,  0.1718],
#         [-0.0683, -0.1200, -0.1970, -0.3026, -0.1007, -0.0646, -0.3316,  0.1702,
#          -0.2431,  0.3074, -0.0196,  0.1474,  0.3122, -0.1371, -0.2362, -0.3675,
#           0.2994, -0.3198, -0.0269,  0.3170,  0.1241,  0.1312, -0.3227,  0.3451,
#           0.1162,  0.1380,  0.2492,  0.0357, -0.1217,  0.1342, -0.2049, -0.0335,
#           0.1333, -0.3542, -0.3847, -0.0775],
#         [ 0.1922,  0.3082,  0.1579,  0.3717, -0.2568,  0.0840,  0.0103,  0.1893,
#          -0.2318,  0.2462,  0.3047, -0.1707, -0.3706,  0.2677,  0.2324, -0.0408,
#          -0.1857, -0.1572, -0.1971,  0.0647, -0.1013, -0.2963,  0.3455,  0.2462,
#           0.1883,  0.1162, -0.1721,  0.0934,  0.2674,  0.3765, -0.1356, -0.3460,
#          -0.2561,  0.1901,  0.3126, -0.0150]], requires_grad=True)}, '_buffers': {}, '_non_persistent_buffers_set': set(), '_backward_pre_hooks': OrderedDict(), '_backward_hooks': OrderedDict(), '_is_full_backward_hook': None, '_forward_hooks': OrderedDict(), '_forward_hooks_with_kwargs': OrderedDict(), '_forward_hooks_always_called': OrderedDict(), '_forward_pre_hooks': OrderedDict(), '_forward_pre_hooks_with_kwargs': OrderedDict(), '_state_dict_hooks': OrderedDict(), '_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_pre_hooks': OrderedDict(), '_load_state_dict_post_hooks': OrderedDict(), '_modules': {'query_proj': Linear(
#   (linear): Linear(in_features=144, out_features=144, bias=True)
# ), 'key_proj': Linear(
#   (linear): Linear(in_features=144, out_features=144, bias=True)
# ), 'value_proj': Linear(
#   (linear): Linear(in_features=144, out_features=144, bias=True)
# ), 'pos_proj': Linear(
#   (linear): Linear(in_features=144, out_features=144, bias=False)
# ), 'dropout': Dropout(p=0.1, inplace=False), 'out_proj': Linear(
#   (linear): Linear(in_features=144, out_features=144, bias=True)
# )}, 'd_model': 144, 'd_head': 36, 'num_heads': 4, 'sqrt_dim': 6.0}

# %%
def visualize_attention_weights(model, input_data, attention_layer_name, num_heads=4):
    """
    Visualizes attention weights from a given attention layer in the Conformer block.
    
    Args:
        model (nn.Module): Trained model with multi-head attention layers.
        input_data (Tensor): The input data (e.g., log-mel spectrogram) to visualize.
        attention_layer_name (str): The name of the attention layer to extract attention weights from.
        num_heads (int): The number of attention heads in the layer.
        
    Returns:
        None (plots the attention heatmap).
    """
    # Set the model to evaluation mode and disable gradient calculation
    model.eval()
    with torch.no_grad():
        # Pass the input through the model to get attention weights
        attention_weights = model(input_data)[attention_layer_name]

        # Visualize attention weights for each attention head
        for i in range(num_heads):
            plt.figure(figsize=(8, 6))
            sns.heatmap(attention_weights[i].cpu().detach().numpy(), cmap='YlGnBu', xticklabels=range(input_data.size(1)),
                        yticklabels=range(input_data.size(1)))
            plt.title(f"Attention Weights - Head {i+1}")
            plt.xlabel("Input Sequence (Time)")
            plt.ylabel("Output Sequence (Time)")
            plt.show()

# print(dataset.samples[0])
logmel = dataset.samples[0]
input_data = torch.tensor(logmel)  # Replace with the log-mel spectrogram from your input
visualize_attention_weights(model, input_data, "conformer_blocks.0.sequential.1.module.attention")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[88], line 33
#      31 logmel = dataset.samples[0]
#      32 input_data = torch.tensor(logmel)  # Replace with the log-mel spectrogram from your input
# ---> 33 visualize_attention_weights(model, input_data, "conformer_blocks.0.sequential.1.module.attention")
#
# Cell In[88], line 18, in visualize_attention_weights(model, input_data, attention_layer_name, num_heads)
#      15 model.eval()
#      16 with torch.no_grad():
#      17     # Pass the input through the model to get attention weights
# ---> 18     attention_weights = model(input_data)[attention_layer_name]
#      20     # Visualize attention weights for each attention head
#      21     for i in range(num_heads):
#
# File /opt/anaconda3/envs/csci1470/lib/python3.11/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/csci1470/lib/python3.11/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[70], line 25, in ConformerClassifier.forward(self, x)
#      23 x = x.squeeze(1)  # From (B, 1, F, T) to (B, F, T)
#      24 x = self.input_proj(x)  # (B, hidden_dim, T)
# ---> 25 x = x.transpose(1, 2)   # (B, T, hidden_dim) for conformer
#      26 x = self.conformer_blocks(x)
#      27 x = x.transpose(1, 2)   # Back to (B, hidden_dim, T)
#
# IndexError: Dimension out of range (expected to be in range of [-2, 1], but got 2)
